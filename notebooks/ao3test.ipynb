# %%
import pandas as pd

# %%
tags = pd.read_csv('tags.csv')
tags
# Out:
#                 id      type                                name  canonical  \
# 0                1     Media                            TV Shows       True
# 1                2     Media                              Movies       True
# 2                3     Media                  Books & Literature       True
# 3                4     Media  Cartoons & Comics & Graphic Novels       True
# 4                5     Media                       Anime & Manga       True
# ...            ...       ...                                 ...        ...
# 14467133  55395603  Freeform                            Redacted      False
# 14467134  55395606  Freeform                            Redacted      False
# 14467135  55395609  Freeform                            Redacted      False
# 14467136  55395612  Freeform                            Redacted      False
# 14467137  55395615  Freeform                            Redacted      False
#
#           cached_count  merger_id
# ...

# %%
tags.value_counts('canonical')
# Out:
# canonical
# False    13291100
# True      1176038
# Name: count, dtype: int64

# %%
tagsn = tags.loc[tags['name'] != 'Redacted']
tagsn
# Out:
#                 id          type  \
# 0                1         Media
# 1                2         Media
# 2                3         Media
# 3                4         Media
# 4                5         Media
# ...            ...           ...
# 14466639  55394121        Fandom
# 14466653  55394163  Relationship
# 14466944  55395036      Freeform
# 14466959  55395081        Fandom
# 14466998  55395198      Freeform
#
#                                                      name  canonical  \
# 0                                                TV Shows       True
# 1                                                  Movies       True
# 2                                      Books & Literature       True
# 3                      Cartoons & Comics & Graphic Novels       True
# 4                                           Anime & Manga       True
# ...                                                   ...        ...
# 14466639                          Brain Dump (Web Series)       True
# ...

# %%
tagstf = tagsn.loc[tagsn['canonical'] == False]
tagstf
# Out:
#                 id          type                            name  canonical  \
# 26              29  Relationship  Sam Winchester/Dean Winchester      False
# 29              33     Character              Impala - Character      False
# 33              37        Fandom          Boondock Saints (1999)      False
# 37              45  Relationship   Viggo Mortensen/Orlando Bloom      False
# 38              46        Fandom           Lord of the Rings RPF      False
# ...            ...           ...                             ...        ...
# 14465147  55389645      Freeform      kid gets pissed constantly      False
# 14465538  55390818   UnsortedTag  Beyond_Kailani need I say more      False
# 14465804  55391616   UnsortedTag                            ceru      False
# 14465862  55391790   UnsortedTag                        jo’s fav      False
# 14466316  55393152   UnsortedTag              бессмертный Вэй Ин      False
#
#           cached_count  merger_id
# ...

# %%
works = pd.read_csv('works.csv')
works
# Out:
#         creation date language  restricted  complete  word_count  \
# 0          2021-02-26       en       False      True       388.0
# 1          2021-02-26       en       False      True      1638.0
# 2          2021-02-26       en       False      True      1502.0
# 3          2021-02-26       en       False      True       100.0
# 4          2021-02-26       en       False      True       994.0
# ...               ...      ...         ...       ...         ...
# 7269688    2008-09-13       en        True      True       705.0
# 7269689    2008-09-13       en       False      True      1392.0
# 7269690    2008-09-13       en       False      True      1755.0
# 7269691    2008-09-13       en       False      True      1338.0
# 7269692    2008-09-13       en       False      True      1836.0
#
#                                                       tags  Unnamed: 6
# 0        10+414093+1001939+4577144+1499536+110+4682892+...         NaN
# ...

# %%
#works.join(works['tags'].str.split('+', n=16, expand=True))

# %%
tag_names = tags.value_counts('name').to_frame()
tag_names = tag_names.reset_index()
tag_names
# Out:
#                                      name     count
# 0                                Redacted  12845163
# 1                                       !         1
# 2                        Phil Wenneck/You         1
# 3                         Phil has issues         1
# 4                               Phil dies         1
# ...                                   ...       ...
# 1621968       Goddess Tower (Fire Emblem)         1
# 1621969                     Goddess Tower         1
# 1621970  Goddess Rhongomyniad | Lion King         1
# 1621971                    Goddess Reader         1
# 1621972                    🥺🥺🥺🥺💕💕💕💕💕💕💕💓💓💓         1
#
# [1621973 rows x 2 columns]

# %%
tags_type = tags.value_counts('type').to_frame()
tags_type
# Out:
#                   count
# type
# Freeform        9244331
# Relationship    2048295
# Character       1509000
# UnsortedTag     1460615
# Fandom           204858
# Category             15
# Media                12
# ArchiveWarning        6
# Rating                6

# %%
tags['name'] = tags['name'].astype('string')
sonic_tags = tags[tags['name'].str.contains("Sonic")]

# %%
# for name in tags
#     if 'Sonic' in name
tags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14467138 entries, 0 to 14467137
# Data columns (total 6 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   id            int64
#  1   type          object
#  2   name          string
#  3   canonical     bool
#  4   cached_count  int64
#  5   merger_id     float64
# dtypes: bool(1), float64(1), int64(2), object(1), string(1)
# memory usage: 565.7+ MB

# %%
#works['tags'] = works['tags'].astype(int)
works.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7269693 entries, 0 to 7269692
# Data columns (total 7 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   creation date  object
#  1   language       object
#  2   restricted     bool
#  3   complete       bool
#  4   word_count     float64
#  5   tags           object
#  6   Unnamed: 6     float64
# dtypes: bool(2), float64(2), object(3)
# memory usage: 291.2+ MB

# %%
sonic_works = pd.merge(works, sonic_tags,
                       left_on='tags', right_on='id', how='inner')
sonic_works
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 sonic_works = pd.merge(works, sonic_tags,
#       2                        left_on='tags', right_on='id', how='inner')
#       3 sonic_works
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:170, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     155     return _cross_merge(
#     156         left_df,
#     157         right_df,
#    (...)
#     167         copy=copy,
#     168     )
#     169 else:
# --> 170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#     173         how=how,
#     174         on=on,
#     175         left_on=left_on,
#     176         right_on=right_on,
#     177         left_index=left_index,
#     178         right_index=right_index,
# ...

# %%
works['tags'] = works['tags'].str.split('+', n=4, expand=True)
works
